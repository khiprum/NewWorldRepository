# %% [markdown]
# <a href="https://colab.research.google.com/github/khiprum/NewWorldRepository/blob/master/%D0%98%D0%BC%D0%BF%D0%BE%D1%80%D1%82%D0%9A%D0%BE%D1%82%D0%B8%D1%80%D0%BE%D0%B2%D0%BE%D0%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install alpha_vantage
# Out:
# ...
#   Created wheel for alpha-vantage: filename=alpha_vantage-2.1.3-cp36-none-any.whl size=14870 sha256=5f4762cd1d8180a606f99343a88a90961adfc16e27f2025b9402f7554b829231
#   Stored in directory: /root/.cache/pip/wheels/d4/75/c2/483b0a988fd965b1128c1396a0ffadfb8903bd2bb569220048
# Successfully built alpha-vantage
# ...

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
tickers_list = ['GAZP.ME', 'SBER.ME']
# Get the data for the stock AAPL
data = pd.DataFrame(columns=tickers_list)
for ticker in tickers_list:
    data[ticker] = yf.download(ticker,'2016-01-01','2019-08-01')['Adj Close']

# Plot all the close prices
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Adjusted Close Price", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
import requests
import alpha_vantage
import json
import matplotlib.pyplot as plt
import numpy as np



API_URL = "https://www.alphavantage.co/query" 
symbols = ['GAZP.ME']

for symbol in symbols:
        data = { "function": "TIME_SERIES_INTRADAY", 
        "symbol": symbol,
        "interval" : "5min",       
        "datatype": "json", 
        "apikey": "NPY0RF7MYJ6KR0R9" } 
        response = requests.get(API_URL, data) 
        data = response.json()
        #print(symbol)
        a = (data['Time Series (5min)'])
        keys = a.keys()
        r = []
        p = []
        for key in keys:
           r.append(a[key]['1. open'])
           p.append(a[key]['4. close'])
 #       print(r," ",p)
        plt.figure(figsize=(60,20))
        plt.plot(r,p,'ro')
        plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()
